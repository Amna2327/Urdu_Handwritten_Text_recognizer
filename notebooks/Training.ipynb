# %%
# %cd /content
# Clone repo
# !git clone https://github.com/Amna2327/Urdu_Handwritten_Text_recognizer

# Create needed folders
# !mkdir -p Urdu_Handwritten_Text_recognizer/checkpoints
# !mkdir -p Urdu_Handwritten_Text_recognizer/data

# Install dependencies
# !pip install -r Urdu_Handwritten_Text_recognizer/requirements.txt

# Kaggle auth + download
import os
os.environ['KAGGLE_API_TOKEN']='YOUR_TOKEN_HERE' 

# !kaggle datasets download ameerhamzaqamar28/nust-uhwr-dataset -p Urdu_Handwritten_Text_recognizer/data
# !unzip -q Urdu_Handwritten_Text_recognizer/data/nust-uhwr-dataset.zip -d Urdu_Handwritten_Text_recognizer/data

# Flatten the double-nested UHWR folder
# !mv Urdu_Handwritten_Text_recognizer/data/DataSet/UHWR/UHWR/* Urdu_Handwritten_Text_recognizer/data/DataSet/UHWR/
# !rmdir Urdu_Handwritten_Text_recognizer/data/DataSet/UHWR/UHWR

# Run training (from repo root, so relative paths in train.py resolve correctly)
# %cd Urdu_Handwritten_Text_recognizer
# !python src/train.py
# Out:
# /content
# Cloning into 'Urdu_Handwritten_Text_recognizer'...
# remote: Enumerating objects: 44, done.
# remote: Counting objects: 100% (44/44), done.
# remote: Compressing objects: 100% (28/28), done.
# Receiving objects: 100% (44/44), 6.91 KiB | 6.91 MiB/s, done.
# Resolving deltas: 100% (16/16), done.
# remote: Total 44 (delta 16), reused 34 (delta 9), pack-reused 0 (from 0)
# ...
# Dataset URL: https://www.kaggle.com/datasets/ameerhamzaqamar28/nust-uhwr-dataset
# License(s): unknown
# ...
# 100% 152M/152M [00:00<00:00, 169MB/s]
#
# /content/Urdu_Handwritten_Text_recognizer
# Traceback (most recent call last):
#   File "/content/Urdu_Handwritten_Text_recognizer/src/train.py", line 74, in <module>
#     main()
#   File "/content/Urdu_Handwritten_Text_recognizer/src/train.py", line 67, in main
#     train_loss=train_one_epoch(model,train_loader,optimizer,criterion)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
# !ls /content/Urdu_Handwritten_Text_recognizer/data/DataSet/UHWR/Dataset/images | wc -l
# Out:
# 10602

# %%
# !ls /content/Urdu_Handwritten_Text_recognizer/data/DataSet/UHWR/Dataset/images | head -20
# Out:
# 00000.jpg
# 00001.jpg
# 00002.jpg
# 00003.jpg
# 00004.jpg
# 00005.jpg
# 00006.jpg
# 00007.jpg
# 00008.jpg
# 00013.jpg
# 00014.jpg
# 00015.jpg
# 00016.jpg
# 00017.jpg
# 00018.jpg
# 00019.jpg
# 00020.jpg
# 00021.jpg
# 00022.jpg
# 00023.jpg

# %%
import os
os.chdir('/content/Urdu_Handwritten_Text_recognizer')
print(os.getcwd())
# !git pull
# !python src/train.py
# Out:
# /content/Urdu_Handwritten_Text_recognizer
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 435 bytes | 435.00 KiB/s, done.
# From https://github.com/Amna2327/Urdu_Handwritten_Text_recognizer
#    5a04abb..29967da  main       -> origin/main
# Updating 5a04abb..29967da
# Fast-forward
#  src/train.py | 1 +
#  1 file changed, 1 insertion(+)
# Skipped files due to incorrect path: 4
# Skipped files due to incorrect path: 0
# Batch number: 100, loss(per batch): 3.0933494567871094
# Batch number: 200, loss(per batch): 3.157522201538086
# Batch number: 300, loss(per batch): 3.133111000061035
# Batch number: 400, loss(per batch): 2.9821927547454834
# Batch number: 500, loss(per batch): 2.9166111946105957
# Batch number: 600, loss(per batch): 2.819005012512207
# ...

# %%
# !zip -r checkpoints.zip checkpoints/
# Out:
#   adding: checkpoints/ (stored 0%)
#   adding: checkpoints/epoch_8.pt (deflated 7%)
#   adding: checkpoints/epoch_1.pt (deflated 8%)
#   adding: checkpoints/epoch_9.pt (deflated 7%)
#   adding: checkpoints/epoch_4.pt (deflated 8%)
#   adding: checkpoints/epoch_3.pt (deflated 8%)
#   adding: checkpoints/epoch_7.pt (deflated 7%)
#   adding: checkpoints/epoch_5.pt (deflated 8%)
#   adding: checkpoints/epoch_6.pt (deflated 8%)
#   adding: checkpoints/epoch_10.pt (deflated 7%)
#   adding: checkpoints/epoch_2.pt (deflated 8%)
