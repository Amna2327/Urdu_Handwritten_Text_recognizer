# %% [markdown]
# <a href="https://colab.research.google.com/github/Amna2327/Urdu_Handwritten_Text_recognizer/blob/main/notebooks/training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Cloning repo

# %%
# %cd /content
# Clone repo
# !git clone https://github.com/Amna2327/Urdu_Handwritten_Text_recognizer

# Create needed folders
# !mkdir -p Urdu_Handwritten_Text_recognizer/checkpoints
# !mkdir -p Urdu_Handwritten_Text_recognizer/data

# Install dependencies
# !pip install -r Urdu_Handwritten_Text_recognizer/requirements.txt
# Out:
# /content
# Cloning into 'Urdu_Handwritten_Text_recognizer'...
# remote: Enumerating objects: 176, done.
# remote: Counting objects: 100% (176/176), done.
# remote: Compressing objects: 100% (113/113), done.
# remote: Total 176 (delta 99), reused 124 (delta 50), pack-reused 0 (from 0)
# Receiving objects: 100% (176/176), 29.85 KiB | 3.73 MiB/s, done.
# Resolving deltas: 100% (99/99), done.
# Collecting pillow==12.3.0 (from -r Urdu_Handwritten_Text_recognizer/requirements.txt (line 1))
#   Using cached pillow-12.3.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (9.1 kB)
# Using cached pillow-12.3.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.9 MB)
# Installing collected packages: pillow
#   Attempting uninstall: pillow
#     Found existing installation: pillow 11.3.0
#     Uninstalling pillow-11.3.0:
#       Successfully uninstalled pillow-11.3.0
# Successfully installed pillow-12.3.0

# %% [markdown]
# Downloading dataset

# %%
# Kaggle auth + download
import os
os.environ['KAGGLE_API_TOKEN'] = 'KGAT_1288e768517287892dbf8a646fe93a18'

# !kaggle datasets download ameerhamzaqamar28/nust-uhwr-dataset -p Urdu_Handwritten_Text_recognizer/data
# !unzip -q Urdu_Handwritten_Text_recognizer/data/nust-uhwr-dataset.zip -d Urdu_Handwritten_Text_recognizer/data

# Flatten the double-nested UHWR folder
# !mv Urdu_Handwritten_Text_recognizer/data/DataSet/UHWR/UHWR/* Urdu_Handwritten_Text_recognizer/data/DataSet/UHWR/
# !rmdir Urdu_Handwritten_Text_recognizer/data/DataSet/UHWR/UHWR
# Out:
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2)
# Dataset URL: https://www.kaggle.com/datasets/ameerhamzaqamar28/nust-uhwr-dataset
# License(s): unknown
# Downloading nust-uhwr-dataset.zip to Urdu_Handwritten_Text_recognizer/data
# 100% 152M/152M [00:05<00:00, 30.9MB/s]

# %% [markdown]
# Training call

# %%
import os
os.chdir('/content/Urdu_Handwritten_Text_recognizer')
print(os.getcwd())
# !git pull
# !python src/train.py
# Out:
# /content/Urdu_Handwritten_Text_recognizer
# Already up to date.
# Skipped files due to incorrect path: 4
# Skipped files due to  width>1400: 373
# Skipped files due to incorrect path: 0
# Skipped files due to  width>1400: 48
# Batch number: 100, loss(per batch): 3.197634696960449
# Batch number: 200, loss(per batch): 3.2303383350372314
# Batch number: 300, loss(per batch): 3.1415460109710693
# Batch number: 400, loss(per batch): 3.270533561706543
# Batch number: 500, loss(per batch): 3.1216824054718018
# epoch: 1, train_loss= 3.2265, val_loss= 3.0188
#   -> new best val_loss, saved checkpoint
# Batch number: 100, loss(per batch): 2.8486199378967285
# Batch number: 200, loss(per batch): 2.4651613235473633
# Batch number: 300, loss(per batch): 2.376819133758545
# Batch number: 400, loss(per batch): 2.3914599418640137
# Batch number: 500, loss(per batch): 1.8518176078796387
# epoch: 2, train_loss= 2.5160, val_loss= 1.9142
#   -> new best val_loss, saved checkpoint
# Batch number: 100, loss(per batch): 1.8278412818908691
# Batch number: 200, loss(per batch): 1.6417351961135864
# Batch number: 300, loss(per batch): 1.6408601999282837
# Batch number: 400, loss(per batch): 1.596670389175415
# Batch number: 500, loss(per batch): 1.2852327823638916
# epoch: 3, train_loss= 1.6933, val_loss= 1.3275
#   -> new best val_loss, saved checkpoint
# Batch number: 100, loss(per batch): 1.581188678741455
# Batch number: 200, loss(per batch): 1.41599440574646
# Batch number: 300, loss(per batch): 1.0446512699127197
# Batch number: 400, loss(per batch): 1.1235525608062744
# Batch number: 500, loss(per batch): 1.5737943649291992
# epoch: 4, train_loss= 1.3122, val_loss= 1.1127
#   -> new best val_loss, saved checkpoint
# Batch number: 100, loss(per batch): 1.0185850858688354
